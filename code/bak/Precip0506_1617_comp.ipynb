# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ee
import geopandas as gp
import rsfuncs as rs
import datetime
import importlib
from dateutil.relativedelta import relativedelta
from datetime import date, timedelta

# %load_ext autoreload
# %autoreload 2

ee.Initialize()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
years = range(2005, 2007)
months = range(1,13)
start = datetime.datetime(years[0], 1, 1)
end = datetime.datetime(years[-1]+1, 1, 1)
dt_idx = pd.date_range(start,end, freq='M')

# %%
shp = gp.read_file("../shape/HU4_merged.shp")
shp.plot()

# %%
area = rs.gdf_to_ee_poly(shp)

# %%
data = rs.load_data()

# %%
prism0506 = rs.get_ims(data['prism'], range(2005,2007), months, area,monthly_mean=True)
prism1617 = rs.get_ims(data['prism'], range(2016,2018), months, area,monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "OREGONSTATE/PRISM/AN81m"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "OREGONSTATE/PRISM/AN81m"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
trmm0506 = rs.get_ims(data['trmm'], range(2005,2007), months, area, monthly_mean=True)
trmm1617 = rs.get_ims(data['trmm'], range(2016,2018), months, area, monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "TRMM/3B43V7"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "TRMM/3B43V7"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
persia0506 = rs.get_ims(data['persia'], range(2005,2007), months, area, monthly_mean=True)
persia1617 = rs.get_ims(data['persia'], range(2016,2018), months, area, monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NOAA/PERSIANN-CDR"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NOAA/PERSIANN-CDR"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
chirps0506 = rs.get_ims(data['chirps'], range(2005,2007), months, area, monthly_mean=True)
chirps1617 = rs.get_ims(data['chirps'], range(2016,2018), months, area, monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "UCSB-CHG/CHIRPS/PENTAD"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "UCSB-CHG/CHIRPS/PENTAD"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
dmet0506 = rs.get_ims(data['dmet'], range(2005,2007), months, area, monthly_mean=True)
dmet1617 = rs.get_ims(data['dmet'], range(2016,2018), months, area, monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/ORNL/DAYMET_V3"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/ORNL/DAYMET_V3"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
# SWE

# %%
fldas_swe0506 = rs.get_ims(data['fldas_swe'], range(2005,2007), months, area, monthly_mean=True)
fldas_swe1617 = rs.get_ims(data['fldas_swe'], range(2016,2018), months, area, monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/FLDAS/NOAH01/C/GL/M/V001"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/FLDAS/NOAH01/C/GL/M/V001"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
gldas_swe0506 = rs.get_ims(data['gldas_swe'], range(2005,2007), months, area, monthly_mean = True)
gldas_swe1617 = rs.get_ims(data['gldas_swe'], range(2016,2018), months, area, monthly_mean = True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/GLDAS/V021/NOAH/G025/T3H"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/GLDAS/V021/NOAH/G025/T3H"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
dmet_swe0506 = rs.get_ims(data['dmet_swe'], range(2005,2007), months, area, monthly_mean = True)
dmet_swe1617 = rs.get_ims(data['dmet_swe'], range(2016,2018), months, area, monthly_mean = True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/ORNL/DAYMET_V3"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "NASA/ORNL/DAYMET_V3"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
# optical - need to prefilter by snowy areas to get full res. Perhaps use elevation?

# %%
mod_0506 = rs.get_ims(data['modis_snow1'], range(2005,2007), months, area, monthly_mean=True)
mod_1618 = rs.get_ims(data['modis_snow1'], range(2016,2018), months, area, monthly_mean=True)
# Out:
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "MODIS/006/MOD10A1"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====
# processing:
# ee.ImageCollection({
#   "type": "Invocation",
#   "arguments": {
#     "id": "MODIS/006/MOD10A1"
#   },
#   "functionName": "ImageCollection.load"
# })
# progress:
# 0.0 %
# 20.0 %
# 40.0 %
# 60.0 %
# 80.0 %
# postprocesing
# ====COMPLETE=====

# %%
len(prism0506), len(persia0506), len(trmm0506), len(chirps0506), len(dmet0506)
# Out:
# (25, 25, 25, 25, 25)

# %%
len(prism1617), len(persia1617), len(trmm1617), len(chirps1617), len(dmet1617)
# Out:
# (25, 25, 25, 25, 25)

# %%
# Compute the sums over hydrological year 05-06 and 16-17 (oct - oct)

sums0506 = []

for i in [prism0506, persia0506, trmm0506, chirps0506, dmet0506]:
    hydro_year = np.nansum(i[9:-3], axis = 0)
    hydro_year[hydro_year == 0] = np.nan
    sums0506.append(hydro_year)

sums1617 = []
    
for i in [prism1617, persia1617, trmm1617, chirps1617, dmet1617]:
    hydro_year = np.nansum(i[9:-3], axis = 0)
    hydro_year[hydro_year == 0] = np.nan
    sums1617.append(hydro_year)
    
diffs = []
for i,x in enumerate(sums0506):
    diffs.append(sums0506[i] - sums1617[i])

# %%
def scale(X, x_min, x_max):
    nom = (X-np.nanmin(X, axis=0))*(x_max-x_min)
    denom = np.nanmax(X, axis=0) - np.nanmin(X, axis=0)
    return x_min + nom/denom

# %%
names = ['PRISM', 'PERSIANN', 'TRMM', 'CHIRPS', 'Daymet']
comparisons = [sums0506, sums1617, diffs, names]

nrows = len(comparisons[0])
ncols = len(comparisons)

vmin = 0

plt.figure(figsize=(10,5))

for idx,x in enumerate(comparisons[0]):
    sum1 = x
    sum2 = comparisons[1][idx]
    diff = comparisons[2][idx]
    scaled = scale(diff,-1,1)
    
    vmax = np.nanmax([sum1,sum2])
    
    plt.figure(figsize=(10,5))
    plt.suptitle(names[idx] + " P (mm)", size = 15)

    plt.subplot(1,3,1)
    plt.title("2005-2006")
    plt.imshow(sum1, vmin = vmin, vmax = vmax, cmap = "Blues")
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.title("2016-2017")
    plt.imshow(sum2, vmin = vmin, vmax = vmax, cmap = "Blues")
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.title("Pixelwise Difference (mm): 05/06 - 16/17")
    plt.imshow(diff, cmap = "jet")
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis("off")

    plt.tight_layout()
    plt.show()
# Out:
# /Users/aakashahamed/anaconda3/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
# Compute the sums over hydrological year 05-06 and 16-17 (oct - oct)

swe_sums0506 = []

for i in [gldas_swe0506, fldas_swe0506, dmet_swe0506, mod_0506]:
    hydro_year = np.nansum(i[9:-3], axis = 0)
    hydro_year[hydro_year == 0] = np.nan
    swe_sums0506.append(hydro_year)

swe_sums1617 = []
    
for i in [gldas_swe1617, fldas_swe1617, dmet_swe1617, mod_1618]:
    hydro_year = np.nansum(i[9:-3], axis = 0)
    hydro_year[hydro_year == 0] = np.nan
    swe_sums1617.append(hydro_year)
    
swe_diffs = []
for i,x in enumerate(swe_sums1617):
    swe_diffs.append(swe_sums0506[i] - swe_sums1617[i])
    
swe_sums0506[-1] = swe_sums0506[-1]*(1/12)
swe_sums1617[-1] = swe_sums1617[-1]*(1/12)
swe_diffs[-1] = swe_diffs[-1]*(1/12)

# %%
swe_names = ['GLDAS SWE ($kg/m^2$)', 'FLDAS SWE ($kg/m^2$)', 'Daymet SWE ($kg/m^2$)', "MODIS (%snowcover)"]
swe_comparisons = [swe_sums0506, swe_sums1617, swe_diffs, swe_names]

nrows = len(comparisons[0])
ncols = len(comparisons)

vmin = 0

plt.figure(figsize=(10,5))

for idx,x in enumerate(swe_comparisons[0]):
    sum1 = x
    sum2 = swe_comparisons[1][idx]
    diff = swe_comparisons[2][idx]
    diff[diff == 0] = np.nan
        
    vmax = np.nanpercentile([sum1,sum2], 99)
    
    plt.figure(figsize=(10,5))
    plt.suptitle(swe_names[idx], size = 15)

    plt.subplot(1,3,1)
    plt.title("2005-2006")
    plt.imshow(sum1, vmin = vmin, vmax = vmax, cmap = "winter_r")
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.title("2016-2017")
    plt.imshow(sum2, vmin = vmin, vmax = vmax, cmap = "winter_r")
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.title("Pixelwise Difference: 05/06 - 16/17")
    plt.imshow(diff, cmap = "cividis")
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Write rasters

# %%
from osgeo import gdal
from osgeo import osr

# %%
# get data from df as arrays
lons = np.array(df.longitude)
lats = np.array(df.latitude)

# get the unique coordinates
uniqueLats = np.unique(lats)
uniqueLons = np.unique(lons)

# get number of columns and rows from coordinates
ncols = len(uniqueLons)    
nrows = len(uniqueLats)

# determine pixelsizes
ys = uniqueLats[1] - uniqueLats[0] 
xs = uniqueLons[1] - uniqueLons[0]

transform = (np.min(uniqueLons),xs,0,np.max(uniqueLats),0,-ys)
 
# set the coordinate system
target = osr.SpatialReference()
target.ImportFromEPSG(4326)
 
# set driver
driver = gdal.GetDriverByName('GTiff')
 
outputDataset = driver.Create("swe1617.tiff", ncols,nrows, 1,gdal.GDT_Float32)
 
# add some metadata
 
outputDataset.SetGeoTransform(transform)
outputDataset.SetProjection(target.ExportToWkt())
outputDataset.GetRasterBand(1).WriteArray(swe1617)
outputDataset.GetRasterBand(1).SetNoDataValue(np.nan)
outputDataset = None
