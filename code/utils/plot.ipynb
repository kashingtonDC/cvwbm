# %%
import os
import geopandas as gp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import fiona
import rasterio
import rasterio.plot
from descartes import PolygonPatch

# %%
shpdir = "../shape"
files = [os.path.join(shpdir,x) for x in os.listdir(shpdir) if x.endswith(".shp")]
files
# Out:
# ['../shape/cv_hu6.shp',
#  '../shape/1803_4.shp',
#  '../shape/1804_4.shp',
#  '../shape/1802_4.shp',
#  '../shape/cv.shp',
#  '../shape/cdec_reservoirs.shp',
#  '../shape/HU4_merged.shp']

# %%
t = gp.read_file(files[0])

# %%
t.plot()
plt.show()

# %%
raster = "/Users/aakashahamed/Desktop/Thesis/GIS/CDL_2017_clip_20180427171422_625011769.tif"
src = rasterio.open(raster)

# %%
rasterio.plot.show((src, 1))
plt.show()
